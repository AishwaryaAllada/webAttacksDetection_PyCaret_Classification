# %% [markdown]
# ## Load the dataset using pandas

# %%
import pandas as pd

logs_dataset = pd.read_csv("/home/akallada/Desktop/projects/sec/logs_dataset.csv")

# %%
logs_dataset.shape
# Out:
# (95695, 7)

# %%
#Take a part of the dataset (10,000), out of 95k daatpoints. 
dataset = logs_dataset[:10000]

# %%
#check the label distribution

dataset['attack'].value_counts()

#highly imbalanced.!!
# Out:
# 0    9890
# 1     110
# Name: attack, dtype: int64

# %% [markdown]
# ## use sample function to split the dataset into train and test

# %%
data = dataset.sample(frac=0.95, random_state=786)
data_unseen = dataset.drop(data.index)
data.reset_index(inplace=True, drop=True)
data_unseen.reset_index(inplace=True, drop=True)
print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (9500, 7)
# Unseen Data For Predictions: (500, 7)

# %%
#import all names from the classification module

from pycaret.classification import *

#setup() used to assign the features and target values to perform classification.
#session ID is to seed in all functions for later reproducibility
exp_name = setup(data = data,  target = 'attack', session_id=123)
# Out:
# <style  type="text/css" >
# </style><table id="T_ef57d5b0_82b8_11eb_947d_8390be8684ad" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ef57d5b0_82b8_11eb_947d_8390be8684adlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_ef57d5b0_82b8_11eb_947d_8390be8684adlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow1_col1" class="data row1 col1" >attack</td>
#             </tr>
#             <tr>
#                         <th id="T_ef57d5b0_82b8_11eb_947d_8390be8684adlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_ef57d5b0_82b8_11eb_947d_8390be8684adlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_ef57d5b0_82b8_11eb_947d_8390be8684adlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow4_col1" class="data row4 col1" >(9500, 7)</td>
#             </tr>
#             <tr>
#                         <th id="T_ef57d5b0_82b8_11eb_947d_8390be8684adlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_ef57d5b0_82b8_11eb_947d_8390be8684adlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow6_col1" class="data row6 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_ef57d5b0_82b8_11eb_947d_8390be8684adlevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow7_col1" class="data row7 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_ef57d5b0_82b8_11eb_947d_8390be8684adlevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_ef57d5b0_82b8_11eb_947d_8390be8684adlevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_ef57d5b0_82b8_11eb_947d_8390be8684adlevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_ef57d5b0_82b8_11eb_947d_8390be8684adlevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow11_col1" class="data row11 col1" >(6649, 1351)</td>
#             </tr>
#             <tr>
#                         <th id="T_ef57d5b0_82b8_11eb_947d_8390be8684adlevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow12_col1" class="data row12 col1" >(2851, 1351)</td>
#             </tr>
#             <tr>
#                         <th id="T_ef57d5b0_82b8_11eb_947d_8390be8684adlevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_ef57d5b0_82b8_11eb_947d_8390be8684adlevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_ef57d5b0_82b8_11eb_947d_8390be8684adlevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_ef57d5b0_82b8_11eb_947d_8390be8684adlevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_ef57d5b0_82b8_11eb_947d_8390be8684adlevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_ef57d5b0_82b8_11eb_947d_8390be8684adlevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_ef57d5b0_82b8_11eb_947d_8390be8684adrow18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>

# %%
# Comparing all models to evaluate performance on the dataset and each of the models performnace is evaluated on 10 fold cross validation.
#the models are compared based on the "Accuracy", which is the default parameter.
best_model = compare_models()
# Out:
# <style  type="text/css" >
#     #T_494bd6f2_82b9_11eb_947d_8390be8684ad th {
#           text-align: left;
#     }#T_494bd6f2_82b9_11eb_947d_8390be8684adrow0_col0,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow0_col2,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow0_col3,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow1_col0,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow1_col1,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow1_col3,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow1_col4,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow1_col5,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow1_col6,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow1_col7,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow2_col0,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow2_col1,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow2_col2,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow2_col3,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow2_col5,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow2_col6,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow2_col7,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow3_col0,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow3_col1,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow3_col2,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow3_col3,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow3_col4,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow3_col5,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow3_col6,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow3_col7,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow4_col0,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow4_col1,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow4_col2,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow4_col3,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow4_col4,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow4_col5,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow4_col6,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow4_col7,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow5_col0,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow5_col1,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow5_col3,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow5_col5,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow5_col6,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow5_col7,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow6_col0,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow6_col1,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow6_col2,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow6_col3,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow6_col4,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow6_col5,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow6_col6,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow6_col7,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow7_col0,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow7_col1,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow7_col2,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow7_col3,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow7_col4,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow7_col5,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow7_col6,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow7_col7,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow8_col0,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow8_col1,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow8_col2,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow8_col3,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow8_col4,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow8_col5,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow8_col6,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow8_col7,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow9_col0,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow9_col1,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow9_col2,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow9_col3,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow9_col4,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow9_col5,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow9_col6,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow9_col7,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow10_col0,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow10_col1,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow10_col2,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow10_col3,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow10_col4,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow10_col5,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow10_col6,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow10_col7,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow11_col0,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow11_col1,#T_494bd6f2_82b9 ...
#             text-align:  left;
#             text-align:  left;
#         }#T_494bd6f2_82b9_11eb_947d_8390be8684adrow0_col1,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow0_col4,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow0_col5,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow0_col6,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow0_col7,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow1_col2,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow2_col4,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow5_col2,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow5_col4,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow12_col3{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_494bd6f2_82b9_11eb_947d_8390be8684adrow0_col8,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow1_col8,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow2_col8,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow4_col8,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow5_col8,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow6_col8,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow7_col8,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow8_col8,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow9_col8,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow10_col8,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow11_col8,#T_494bd6f2_82b9_11eb_947d_8390be8684adrow12_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_494bd6f2_82b9_11eb_947d_8390be8684adrow3_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_494bd6f2_82b9_11eb_947d_8390be8684ad" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_494bd6f2_82b9_11eb_947d_8390be8684adlevel0_row0" class="row_heading level0 row0" >ridge</th>
#                         <td id="T_494bd6f2_82b9_11eb_947d_8390be8684adrow0_col0" class="data row0 col0" >Ridge Classifier</td>
#                         <td id="T_494bd6f2_82b9_11eb_947d_8390be8684adrow0_col1" class="data row0 col1" >0.9995</td>
#                         <td id="T_494bd6f2_82b9_11eb_947d_8390be8684adrow0_col2" class="data row0 col2" >0.0000</td>
#                         <td id="T_494bd6f2_82b9_11eb_947d_8390be8684adrow0_col3" class="data row0 col3" >0.9548</td>
#                         <td id="T_494bd6f2_82b9_11eb_947d_8390be8684adrow0_col4" class="data row0 col4" >1.0000</td>
#                         <td id="T_494bd6f2_82b9_11eb_947d_8390be8684adrow0_col5" class="data row0 col5" >0.9755</td>
#                         <td id="T_494bd6f2_82b9_11eb_947d_8390be8684adrow0_col6" class="data row0 col6" >0.9753</td>
#                         <td id="T_494bd6f2_82b9_11eb_947d_8390be8684adr

# %%
# The best model is highlighed in yellow from the above table.
# we can also print to check the best model and its parameters.
print(best_model)
# Out:
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                 max_iter=None, normalize=False, random_state=123, solver='auto',
#                 tol=0.001)

# %%
# we can specifically create a model using create_model() and can further tune them using tune_model()
predict_model(best_model);
# Out:
# <style  type="text/css" >
# </style><table id="T_4957897a_82b9_11eb_947d_8390be8684ad" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4957897a_82b9_11eb_947d_8390be8684adlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4957897a_82b9_11eb_947d_8390be8684adrow0_col0" class="data row0 col0" >Ridge Classifier</td>
#                         <td id="T_4957897a_82b9_11eb_947d_8390be8684adrow0_col1" class="data row0 col1" >0.9989</td>
#                         <td id="T_4957897a_82b9_11eb_947d_8390be8684adrow0_col2" class="data row0 col2" >0.9531</td>
#                         <td id="T_4957897a_82b9_11eb_947d_8390be8684adrow0_col3" class="data row0 col3" >0.9062</td>
#                         <td id="T_4957897a_82b9_11eb_947d_8390be8684adrow0_col4" class="data row0 col4" >1.0000</td>
#                         <td id="T_4957897a_82b9_11eb_947d_8390be8684adrow0_col5" class="data row0 col5" >0.9508</td>
#                         <td id="T_4957897a_82b9_11eb_947d_8390be8684adrow0_col6" class="data row0 col6" >0.9503</td>
#                         <td id="T_4957897a_82b9_11eb_947d_8390be8684adrow0_col7" class="data row0 col7" >0.9515</td>
#             </tr>
#     </tbody></table>

# %%
# finalize_model() - fits the model onto the complete dataset including the test/hold-out sample
# final_model = finalize_model(best_model)

# %%
# print(final_model)

# %% [markdown]
# ## Predict model on unseen data

# %%
unseen_predictions = predict_model(final_model, data=data_unseen)
unseen_predictions.head()
# Out:
#    Unnamed: 0  size  param_number  length  return_code  \
# 0           5   295             1      26          404
# 1          18   295             1      26          404
# 2          37   295             1      26          404
# 3          39   518             1      24          301
# 4          57  1432             1      47          200
#
#                                                url  attack  Label
# 0                       GET /wp-login.php HTTP/1.1       0      0
# 1                       GET /wp-login.php HTTP/1.1       0      0
# 2                       GET /wp-login.php HTTP/1.1       0      0
# 3                         GET /robots.txt HTTP/1.1       0      0
# 4  GET /self.logs/error.log.2015-12-20.gz HTTP/1.1       0      0

# %%
#check_metric function is used to evaluate the model on the test data, based on the metric specified. 

from pycaret.utils import check_metric
check_metric(unseen_predictions['attack'], unseen_predictions['Label'], metric = 'Accuracy')
# Out:
# 1.0

# %% [markdown]
# ## saving the model

# %%
save_model(final_model,'final_model_web_attacks')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='attack',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strat...
#                  ('fix_perfect', Remove_100(target='attack')),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True,
#                                   fit_intercept=True, max_iter=None,
#                                   normalize=False, random_state=123,
#                                   solver='auto', tol=0.001)]],
#           verbose=False),
#  'final_model_web_attacks.pkl')

# %% [markdown]
# ## Loading the model

# %%
saved_final_rf = load_model('final_model_web_attacks')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
new_prediction = predict_model(saved_final_rf, data=data_unseen)

# %%
new_prediction.head()
# Out:
#    Unnamed: 0  size  param_number  length  return_code  \
# 0           5   295             1      26          404
# 1          18   295             1      26          404
# 2          37   295             1      26          404
# 3          39   518             1      24          301
# 4          57  1432             1      47          200
#
#                                                url  attack  Label
# 0                       GET /wp-login.php HTTP/1.1       0      0
# 1                       GET /wp-login.php HTTP/1.1       0      0
# 2                       GET /wp-login.php HTTP/1.1       0      0
# 3                         GET /robots.txt HTTP/1.1       0      0
# 4  GET /self.logs/error.log.2015-12-20.gz HTTP/1.1       0      0

# %%
from pycaret.utils import check_metric
check_metric(new_prediction['attack'], new_prediction['Label'], metric = 'Accuracy')
# Out:
# 1.0
